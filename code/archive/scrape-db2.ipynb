# %%
from bs4 import BeautifulSoup
import requests
import httpx
import pandas as pd
import numpy as np

# %%
class trialContextManager:
    def __enter__(self): pass
    def __exit__(self, *args): return True
trial = trialContextManager()

# %%
base_url = 'https://www.aup.nl/en/journal/mens-en-maatschappij/back-issues'
url = 'https://journal-archive.aup.nl'

# %%
def get_article_urls(base_url):
    r = requests.get(base_url)
    soup = BeautifulSoup(r.content, 'lxml')
    hrefs = soup.find_all("a")
    article_urls = [href for href in hrefs if 'journal-downloads' in href.get('href')]
    return(article_urls)

# %%
def urls_to_df(article_urls):
    hold = []
    for a in article_urls:
        href = url + a.get('href').replace('/journal-downloads', '')
        issue, title = a.text.split(' - ')
        issue = issue.replace('no', 'No')
    
        hold.append([href, issue, title])
    
    df = pd.DataFrame(hold)\
        .set_axis(['pdf_url', 'issue', 'title'], axis=1)
    return(df)

# %%
def add_section(df):
    df['Boekbespreking'] = df['title'].str.contains('Boekbespreking')
    df['Algemeen'] = (df.groupby('issue').cumcount() == 0)\
        | df['title'].str.contains('Rectificatie')\
        | df['title'].str.contains('In memoriam')\
        | df['title'].str.contains('Ontvangen publicaties')\
        | df['title'].str.match('Van Doorns Indische lessen')
    df['section'] = 'artikel'
    df['section'] = df['section'].mask(df['Boekbespreking'], 'boekbespreking').mask(df['Algemeen'], 'algemeen') 
    return(df.drop(['Boekbespreking', 'Algemeen'], axis=1))

# %%
def add_id_and_year(df):
    df ['id'] = 'article-' + \
        df['issue'].str.extractall('(\d)')\
            .reset_index()\
            .set_axis(['idx', 'match', 'number'], axis=1)\
            .groupby('idx')['number'].sum() + \
            (df.groupby('issue').cumcount() + 1).astype(str).str.zfill(2)
    
    df['year'] = df['issue'].str.extract('(\d+)').astype(int) + 1925
    df['issue'] = df['issue'] + ' (' + df['year'].astype(str) + ')'
    return(df)

# %%
article_urls = get_article_urls(base_url)
df = urls_to_df(article_urls)\
    .pipe(add_section)\
    .pipe(add_id_and_year)\
    .assign(database = 2)

# %%
df.to_csv('scraped_data2.csv', index=False)

# %%
# Out:
#                                                pdf_url               issue  \
# 0    https://journal-archive.aup.nl/mens-en-maatsch...  Vol 83 No 1 (2008)
# 1    https://journal-archive.aup.nl/mens-en-maatsch...  Vol 83 No 1 (2008)
# 2    https://journal-archive.aup.nl/mens-en-maatsch...  Vol 83 No 1 (2008)
# 3    https://journal-archive.aup.nl/mens-en-maatsch...  Vol 83 No 1 (2008)
# 4    https://journal-archive.aup.nl/mens-en-maatsch...  Vol 83 No 1 (2008)
# ..                                                 ...                 ...
# 192  https://journal-archive.aup.nl/mens-en-maatsch...  Vol 77 No 3 (2002)
# 193  https://journal-archive.aup.nl/mens-en-maatsch...  Vol 77 No 3 (2002)
# 194  https://journal-archive.aup.nl/mens-en-maatsch...  Vol 77 No 3 (2002)
# 195  https://journal-archive.aup.nl/mens-en-maatsch...  Vol 77 No 3 (2002)
# 196  https://journal-archive.aup.nl/mens-en-maatsch...  Vol 77 No 3 (2002)
#
#                                                  title         section  \
# 0                  Effectevaluaties wetenschappelijker        algemeen
# 1      Meningen over abortus in West-Europa, 1981-2000         artikel
# 2    De electorale steun voor de Nationaal Socialis...         artikel
# 3                           Vrijheid versus veiligheid         artikel
# 4                                   Hoe meet ik beroep         artikel
# ..                                                 ...             ...
# 192   Ontvangen publicaties Mens & Maatschappij 2002-3        algemeen
# 193                                  Op welke leeftijd         artikel
# 194                   Van groeikern tot Deltametropool         artikel
# 195                               Mensbeeld en methode         artikel
# 196  Boekbespreking Een rapsodisch leven. Herinneri...  boekbespreking
#
#                 id  year  database
# 0    article-83101  2008         2
# 1    article-83102  2008         2
# 2    article-83103  2008         2
# 3    article-83104  2008         2
# 4    article-83105  2008         2
# ..             ...   ...       ...
# 192  article-77303  2002         2
# 193  article-77304  2002         2
# 194  article-77305  2002         2
# 195  article-77306  2002         2
# 196  article-77307  2002         2
#
# [197 rows x 7 columns]
